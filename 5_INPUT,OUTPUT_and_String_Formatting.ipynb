# %% [markdown]
# # **INPUT AND OUTPUT**

# %%
name = input("Enter your name: ")

print(name)
# Out:
# Enter your name: Emin
# Emin

# %% [markdown]
# - input() waits for user input
# - Whatever the user types becomes a string
# - The value is stored in the variable name

# %%
name=input("Enter your name:")
print("His name is:",name)
print(type(name))

age=input("Enter your age:")
print(type(age))
# Out:
# Enter your name:Chinnu
# His name is: Chinnu
# <class 'str'>
# Enter your age:30
# <class 'str'>

# %% [markdown]
# ## Input With Message

# %%
city = input("Which city do you live in? ")

print("You live in", city)
# Out:
# Which city do you live in? Manjeri
# You live in Manjeri

# %%
age=int(input("Enter your age:"))
print("He is",age,"years old")
type(age)
# Out:
# Enter your age:30
# He is 30 years old
# int

# %% [markdown]
# ## *Input Always Returns String*

# %%
# input() always takes data as string

name = input("Enter your name: ")
print("Name:", name)
# Out:
# Enter your name: Rahul
# Name: Rahul

# %%
age = input("Enter your age: ")

print(age)
print(type(age))
# Out:
# Enter your age: 30
# 30
# <class 'str'>

# %% [markdown]
# Even numbers entered using input() are treated as strings.

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

# print(num1 + num2)          error

print(int(num1) + int(num2))
# Out:
# Enter first number: 4
# Enter second number: 5
# 9

# %% [markdown]
# ## Converting Input to Integer5

# %%
age = int(input("Enter your age: "))

print(age)
print(type(age))
# Out:
# Enter your age: 45
# 45
# <class 'int'>

# %%
# input for float value
salary = float(input("Enter your salary: "))

print("Salary is:", salary)
# Out:
# Enter your salary: 454654
# Salary is: 454654.0

# %% [markdown]
# ## Simple Addition Program

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum_result = num1 + num2

print("Sum =", sum_result)
# Out:
# Enter first number: 34
# Enter second number: 56
# Sum = 90

# %% [markdown]
# # **String Formatting**

# %%
name = "Aman"
age = 22

print("Name is", name, "and age is", age)
# Out:
# Name is Aman and age is 22

# %% [markdown]
# ## String Concatenation

# %%
name = "Aman"

print("Hello " + name)
# Out:
# Hello Aman

# %%
age = 25

# ERROR
# print("Age is " + age)

# Correct
print("Age is " + str(age))
# Out:
# Age is 25

# %% [markdown]
# ## Using format() Method

# %%
name = "Priya"
age = 21

message = "My name is {} and I am {} years old.".format(name, age)

print(message)
# Out:
# My name is Priya and I am 21 years old.

# %% [markdown]
# ## Indexed Formatting

# %%
item = "Laptop"
price = 55000

print("Item: {0}, Price: {1}".format(item, price))
# Out:
# Item: Laptop, Price: 55000

# %% [markdown]
# ## Named Formatting

# %%
print("Name: {n}, Age: {a}".format(n="Ravi", a=24))
# Out:
# Name: Ravi, Age: 24

# %% [markdown]
# ## **f-Strings**

# %%
name = "Anita"
marks = 92

print(f"{name} scored {marks} marks.")
# Out:
# Anita scored 92 marks.

# %% [markdown]
# - f stands for formatted string
# - Variables can be directly used inside {}

# %% [markdown]
# ### Expressions Inside f-Strings

# %%
a = 10
b = 20

print(f"Sum = {a + b}")
print(f"Multiplication = {a * b}")
# Out:
# Sum = 30
# Multiplication = 200

# %% [markdown]
# ### Formatting Decimal Values

# %%
pi = 3.1415926535

print(f"Value of pi = {pi:.2f}")
# .2f means 2 digits after decimal
# Out:
# Value of pi = 3.14

# %% [markdown]
# ### Aligning Text

# %%
name = "Rahul"
score = 88

print(f"{name:<10} {score}")
print(f"{name:>10} {score}")
print(f"{name:^10} {score}")
# Out:
# Rahul      88
#      Rahul 88
#   Rahul    88

# %% [markdown]
# - `<` Left align
# - `>` Right align
# - `^` Center align

# %% [markdown]
# ### Percentage Formatting

# %%
marks = 87.4567

print(f"Percentage = {marks:.1f}%")
# Out:
# Percentage = 87.5%

# %% [markdown]
# ## USING QUOTES FOR A STATEMENT

# %%
print('"Hello, World!"')       #Use Single Quotes to Wrap the String

print("\"Hello, World!\"")     #Use Escape Character (\) Before Double Quotes

print("""She said, "Python is fun!" """)   # print("""She said, "Python is fun!" """)

#print("She said, "Hello"")   #ERROR
# Out:
# "Hello, World!"
# "Hello, World!"
# She said, "Python is fun!"

# %%
print(' """"hi"""" ')
# Out:
#  """"hi""""

# %%
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))

print("Before swapping: x =", x, "y =", y)

x, y= y,x

print("After swapping: x =", x, "y =", y)
# Out:
# Enter first number: 23
# Enter second number: 23
# Before swapping: x = 23 y = 23
# After swapping: x = 23 y = 23

# %%
name = "Alice"
marks = 85

# Method 1: Using comma
print("Name:", name, "Marks:", marks)

# Method 2: f-string (best)
print(f"Name: {name}, Marks: {marks}")

# Method 3: format()
print("Name: {}, Marks: {}".format(name, marks))
# Out:
# Name: Alice Marks: 85
# Name: Alice, Marks: 85
# Name: Alice, Marks: 85

# %% [markdown]
# # Practice Questions

# %% [markdown]
# 1. Take two numbers as input and display multiplication.
# 2. Take student details and display them using f-strings.
# 3. Build a temperature converter.
# 4. Create a grocery bill generator.
# 5. Calculate simple interest using user input.

# %%
PI = 3.14159
radius = float(input('Enter radius: '))
area = PI * radius ** 2
print('Area:', area)

# %%
name = input("Enter your name: ")
python_marks = float(input("Enter Python marks: "))
sql_marks = float(input("Enter SQL marks: "))

average = (python_marks + sql_marks) / 2

print("\n===== REPORT CARD =====")

print(f"Student Name : {name}")
print(f"Python Marks : {python_marks:.2f}")
print(f"SQL Marks    : {sql_marks:.2f}")
print(f"Average      : {average:.2f}")
# Out:
# Enter your name: FGR
# Enter Python marks: 454
# Enter SQL marks: 5
#
# ===== REPORT CARD =====
# Student Name : FGR
# Python Marks : 454.00
# SQL Marks    : 5.00
# Average      : 229.50

# %%
product = input("Enter product name: ")
price = float(input("Enter product price: "))
quantity = int(input("Enter quantity: "))

total = price * quantity

print("\n========== BILL ==========")
print(f"Product Name : {product}")
print(f"Price        : ₹{price:.2f}")
print(f"Quantity     : {quantity}")
print(f"Total Amount : ₹{total:.2f}")
print("==========================")
# Out:
# Enter product name: THH
# Enter product price: 56
# Enter quantity: 54
#
# ========== BILL ==========
# Product Name : THH
# Price        : ₹56.00
# Quantity     : 54
# Total Amount : ₹3024.00
# ...
